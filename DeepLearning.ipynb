# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaeYun430/DeepLearningStudy25/blob/master/DeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * 머신러닝 : 애플리케이션을 수정하지 않고도 데이터를 기반으로 패턴을 학습하고 결과를 예측하는 알고리즘 기법
#
# * 학습(training) : 데이터가 입력되고 패턴이 분석되는 과정
# * 지도학습
#   * 분류
#   * 회귀
#   * 추천 시스템
#   * 시각,음성 감지,인지
#   * 텍스트 분석, NLP
#
# * 비지도 학습
#   * 클러스터링
#   * 차원 축소
#   * 강화학습
#
# * 머신러닝 모델을 개선하기 위해서는
#   * 최적의 머신러닝 알고리즘과모델 파라미터를 구축
#   * 데이터를 이해하고
#   * 효율적으로 가공, 처리, 추출해 최적의 데이터를 기반으로 알고리즘을 구동할 수 있도록 준비하는 능력
#
# * 주요 패키지
#   * 머신러닝
#   * 행렬/선형대수/통계
#   * 데이터 핸들링
#   * 시각화
#
# * 딥러닝을 설계한다는 것은 다음을 고민하는 것
#   * 몇 개의 층을 어떻게 쌓을지
#   * Dense 욍 어떤 층을 사용할지
#   * 내부의 변수들을 어떻게 정해야 하는지
#   * 이러한 딥러닝 구조의 구동과 마무리 방식에 대한 설정 옵션

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# * 선형 회귀(simple/multiple linear regression) : 독립변수 x를 사용해 종속변수 y의  움직임을 예측하고 설명하는 작업
#
# * 최소 제곱법(method of least squares)
